# %%
import geopandas as gp

import pandas as pd
import matplotlib

data= gp.read_file(r'/Users/tory/Desktop/week 8/Stadiums_MLB/Stadiums_MLB.shp')

capacity= data.CAPACITY
latitude = data.LATITUDE
x = capacity
y = latitude
s =  500

plt.scatter(x, y, s, c="b", alpha=0.5, marker=r'p',
            label="Ballpark")
plt.xlabel("Stadium Capacity")
plt.ylabel("Latitude")
plt.legend(loc='lower right')
plt.show()
